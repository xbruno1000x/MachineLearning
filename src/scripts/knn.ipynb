# %%
from pathlib import Path
import pandas as pd

csv_path = Path('../data/loan_risk_balanceado.csv')
df = pd.read_csv(csv_path)
df.head(5)
# Out:
#    Age   Income  LoanAmount  CreditScore  YearsExperience  Gender  \
# 0   43  54281.0     17379.0        553.0               27    Male
# 1   39  46908.0     17793.0        685.0               11  Female
# 2   56  59826.0     18553.0        784.0                9    Male
# 3   31  48080.0     26708.0        776.0               39  Female
# 4   23  47751.0     20556.0        583.0               12    Male
#
#      Education           City EmploymentType  LoanApproved
# 0          PhD  San Francisco       Salaried             0
# 1  High School        Chicago       Salaried             1
# 2          PhD  San Francisco  Self-Employed             1
# 3          PhD  San Francisco  Self-Employed             1
# 4  High School  San Francisco  Self-Employed             0

# %%
df.value_counts('EmploymentType')
# Out:
# EmploymentType
# Self-Employed    902
# Salaried         876
# Unemployed       524
# Name: count, dtype: int64

# %%
categoricasOrdinais = [
    {
        'nome': 'Gender'
    },
    {
        'nome': 'Education',
        'ordem': ['High School', 'Bachelor', 'Master', 'PhD']
    },
    {
        'nome': 'EmploymentType',
        'ordem': ['Unemployed', 'Salaried', 'Self-Employed']
    }
]

# %%
configs = {
    "nome_arquivo": Path('../data/loan_risk_balanceado.csv'),
    "cols_dummy": ['City'],
    "cols_categoria_ordinal": categoricasOrdinais
}

# %%
from models.classificador import Classificador
from models.pre_processador import PreProcessador
from models.metrificador import Metrificador

pre_processador = PreProcessador(configs)
classificador = Classificador(pre_processador)

resultados = []
for k in range(1, 100):
    classificador.KNN(k)
    metrificador = Metrificador(classificador)
    acuracia = metrificador.acuracia()
    matriz_confusao = metrificador.matrizConfusao()
    resultados.append({
        "k": k,
        "acuracia": acuracia,
        "matriz_confusao": matriz_confusao
    })

resultados_df = pd.DataFrame(resultados)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 5
#       2 from models.pre_processador import PreProcessador
#       3 from models.metrificador import Metrificador
# ----> 5 pre_processador = PreProcessador(configs)
#       6 classificador = Classificador(pre_processador)
#       8 resultados = []
#
# File C:\Projects\Personal\MachineLearningCefet\Loan-Risk-Classification\src\models\pre_processador.py:24, in PreProcessador.__init__(self, configs)
#      22 self.prepararBase(self.configs)
#      23 self.separarPrevisoresDaClasse(self.configs["col_classe"])
# ---> 24 self.preProcessar(self.configs)
#
# File C:\Projects\Personal\MachineLearningCefet\Loan-Risk-Classification\src\models\pre_processador.py:128, in preProcessar(self, configs)
#     122 def padronizarDados(self):
#     123 	valores_escalados = self.scaler.fit_transform(self.previsores)
#     124 	self.previsores = pd.DataFrame(
#     125 		valores_escalados,
#     126 		columns=self.cols_previsores,
#     127 		index=self.base.index,
# --> 128 	)
#
# File C:\Projects\Personal\MachineLearningCefet\Loan-Risk-Classification\src\models\pre_processador.py:102, in PreProcessador.transformarVariavelCategoriaOrdinal(self, nome_col)
#     101 def transformarVariavelCategoriaOrdinal(self, col):
# --> 102 	if col.nome not in self.previsores.columns:
#     103 		return
#     105 	labelEnconder = LabelEncoder()
#
# File c:\Users\Saulo Klein\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:5358, in Index.__contains__(self, key)
#    5323 def __contains__(self, key: Any) -> bool:
#    5324     """
#    5325     Return a boolean indicating whether the provided key is in the index.
#    5326
#    (...)
#    5356     False
#    5357     """
# -> 5358     hash(key)
#    5359     try:
#    5360         return key in self._engine
#
# TypeError: unhashable type: 'dict'

# %%
resultados_df.sort_values(by='acuracia', ascending=False).head(10)

# %%
print(f"Acurácia: {acuracia}"
      f"\nMatriz de Confusão:\n{matriz_confusao}")

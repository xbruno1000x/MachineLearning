# %%
import pandas as pd
from pathlib import Path

csv_path = Path('../data/loan_risk_balanceado.csv')
df = pd.read_csv(csv_path)

# %%
df.value_counts('LoanApproved')
# Out:
# LoanApproved
# 0    3849
# 1    1151
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#                Age        Income    LoanAmount  CreditScore  YearsExperience  \
# count  2302.000000   2302.000000   2302.000000  2302.000000      2302.000000
# mean     43.740660  51512.302780  19861.301043   617.417463        19.461772
# std      14.730937  13849.506051   8191.067605   155.547737        11.462315
# min      18.000000  -3731.000000  -5728.000000   300.000000         0.000000
# 25%      31.000000  43122.250000  14406.500000   500.000000        10.000000
# 50%      43.000000  50429.500000  19778.000000   646.000000        19.000000
# 75%      56.750000  60135.250000  25260.500000   747.000000        29.000000
# max      69.000000  98602.000000  48353.000000   849.000000        39.000000
#
#        LoanApproved
# count   2302.000000
# mean       0.500000
# std        0.500109
# min        0.000000
# 25%        0.000000
# 50%        0.500000
# 75%        1.000000
# max        1.000000

# %%
configs = {
    
}

# %%
from models.pre_processador import PreProcessador

p = PreProcessador(configs)
